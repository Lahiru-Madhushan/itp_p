# %%
import numpy as np

# %%
import json 
with open('../artifacts/kaggle.json','r') as file:
    data=json.load(file)

# %%
data
# Out:
# {'username': 'madhushanl', 'key': 'cf88d9769be97a32042985f93bab9f08'}

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\python\lib\site-packages (1.7.4.5)
# Requirement already satisfied: bleach in c:\python\lib\site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\python\lib\site-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: charset-normalizer in c:\python\lib\site-packages (from kaggle) (3.4.0)
# Requirement already satisfied: idna in c:\python\lib\site-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in c:\python\lib\site-packages (from kaggle) (6.31.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\python\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\python\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in c:\python\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in c:\python\lib\site-packages (from kaggle) (65.5.0)
# Requirement already satisfied: six>=1.10 in c:\python\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: text-unidecode in c:\python\lib\site-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in c:\python\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in c:\python\lib\site-packages (from kaggle) (2.2.3)
# Requirement already satisfied: webencodings in c:\python\lib\site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: colorama in c:\python\lib\site-packages (from tqdm->kaggle) (0.4.6)
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.environ['KAGGLE_USERNAME']=data['username']
os.environ['KAGGLE_KEY']=data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset', path ='../artifacts')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
import zipfile
with zipfile.ZipFile('../artifacts/sentiment-analysis-dataset.zip','r') as zip_ref:
    zip_ref.extractall('../artifacts/')
